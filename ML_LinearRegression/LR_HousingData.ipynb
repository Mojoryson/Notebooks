# %% [markdown]
# ### Linear Regression Project using US Housing Data
#
# DESCRIPTION:
#  * This project involves implementing a Linear Regression model using US Housing Data.
#  * The goal is to analyze and predict housing prices based on various features such as
#  * location, size, number of bedrooms, and other relevant factors. The project includes data preprocessing, model training, evaluation, and visualization of results.

# %%
#Install the required packages
# %pip install numpy
# %pip install matplotlib
# %pip install seaborn
# %pip install pandas
# Out:
# ...
#   Using cached numpy-2.1.3-cp312-cp312-macosx_14_0_x86_64.whl.metadata (62 kB)
# Using cached numpy-2.1.3-cp312-cp312-macosx_14_0_x86_64.whl (6.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 9.0 MB/s eta 0:00:00:00:0100:01
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 14.7 MB/s eta 0:00:0000:01
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached pandas-2.2.3-cp312-cp312-macosx_10_9_x86_64.whl.metadata (89 kB)
# ...
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...

# %%
# !pip list
# Out:
# Package            Version
# ------------------ -----------
# appnope            0.1.4
# asttokens          2.4.1
# comm               0.2.2
# contourpy          1.3.1
# cycler             0.12.1
# debugpy            1.6.7
# decorator          5.1.1
# exceptiongroup     1.2.2
# executing          2.1.0
# fonttools          4.55.0
# importlib_metadata 8.5.0
# ipykernel          6.29.5
# ipython            8.29.0
# jedi               0.19.2
# jupyter_client     8.6.3
# jupyter_core       5.7.2
# kiwisolver         1.4.7
# matplotlib         3.9.2
# matplotlib-inline  0.1.7
# nest_asyncio       1.6.0
# numpy              2.1.3
# packaging          24.2
# pandas             2.2.3
# parso              0.8.4
# pexpect            4.9.0
# pickleshare        0.7.5
# pillow             11.0.0
# pip                24.2
# platformdirs       4.3.6
# prompt_toolkit     3.0.48
# psutil             5.9.0
# ptyprocess         0.7.0
# pure_eval          0.2.3
# Pygments           2.18.0
# ...

# %%
import sys
print(sys.executable)
# Out:
# /Users/rmorrison/anaconda3/envs/ai_dev/bin/python

# %%
# Import the necessary libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns # Seaborn is a Python data visualization library based on matplotlib.
# %matplotlib inline

# %%
# Load the dataset into a pandas dataframe
df_housing = pd.read_csv('data/USA_housing.csv')

# %%
# Display the first 5 rows of the dataframe
df_housing.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...
